# %% [markdown]
# # Ejercicios de Seaborn

# %%
# 1. Importa pandas, pyplot y seaborn
import pandas as pd
from sklearn.datasets import load_iris
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
# 4. Mira las primeras filas del dataset para hacerte una idea de los datos cargados
url = (r"data/pokemon.csv")

pokemon = pd.read_csv(url)

# %%
pokemon.head(10)
# Out:
#     #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0   1   Bulbasaur  Grass  Poison    318  45      49       49       65
# 1   2     Ivysaur  Grass  Poison    405  60      62       63       80
# 2   3    Venusaur  Grass  Poison    525  80      82       83      100
# 3   4  Charmander   Fire     NaN    309  39      52       43       60
# 4   5  Charmeleon   Fire     NaN    405  58      64       58       80
# 5   6   Charizard   Fire  Flying    534  78      84       78      109
# 6   7    Squirtle  Water     NaN    314  44      48       65       50
# 7   8   Wartortle  Water     NaN    405  59      63       80       65
# 8   9   Blastoise  Water     NaN    530  79      83      100       85
# 9  10    Caterpie    Bug     NaN    195  45      30       35       20
#
#    Sp. Def  Speed  Stage  Legendary
# 0       65     45      1      False
# 1       80     60      2      False
# 2      100     80      3      False
# 3       50     65      1      False
# 4       65     80      2      False
# 5       85    100      3      False
# 6       64     43      1      False
# 7       80     58      2      False
# 8      105     78      3      False
# 9       20     45      1      False

# %%
pokemon.set_index("#", inplace=True)

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 151 entries, 1 to 151
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       151 non-null    object
#  1   Type 1     151 non-null    object
#  2   Type 2     67 non-null     object
#  3   Total      151 non-null    int64
#  4   HP         151 non-null    int64
#  5   Attack     151 non-null    int64
#  6   Defense    151 non-null    int64
#  7   Sp. Atk    151 non-null    int64
#  8   Sp. Def    151 non-null    int64
#  9   Speed      151 non-null    int64
#  10  Stage      151 non-null    int64
#  11  Legendary  151 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 14.3+ KB

# %%
# 5. Haz un scatter plot con lmplot(), que es el método que pinta una regresión lineal
# Pasa el DataFrame como argumento del método en el parámetro llamado data

sns.lmplot(x="Attack", y= "Defense" ,data=pokemon, hue= "Legendary" , fit_reg=True);

# %%
# y = a*x + b
# 50 = a *40 + b

# %%
# 6. No queremos ver la línea recta de la regresión lineal.
# prueba a añadir fit_reg a falso
sns.lmplot(x="Attack", y= "Defense" ,data=pokemon, hue= "Stage" , fit_reg=False);
plt.grid()

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 151 entries, 1 to 151
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       151 non-null    object
#  1   Type 1     151 non-null    object
#  2   Type 2     67 non-null     object
#  3   Total      151 non-null    int64
#  4   HP         151 non-null    int64
#  5   Attack     151 non-null    int64
#  6   Defense    151 non-null    int64
#  7   Sp. Atk    151 non-null    int64
#  8   Sp. Def    151 non-null    int64
#  9   Speed      151 non-null    int64
#  10  Stage      151 non-null    int64
#  11  Legendary  151 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 14.3+ KB

# %%
# 7. Vamos a decir qué variable (columna del DataFrame) codifica los colores (hue)
# Que el hue sea el Stage
sns.lmplot(x="Attack", y= "Defense" ,data=pokemon, hue= "Stage" , fit_reg=False);

# %%
# 8. Limita el eje x entre 20 y 100
sns.lmplot(x="Attack", y= "Defense" ,data=pokemon, hue= "Legendary" , fit_reg=False)
plt.xlim(20,100)
# Out:
# (20.0, 100.0)

# %%
# 9. Dibuja un diagrama de cajas con el dataframe
plt.figure(figsize=(15,10))
sns.boxplot(data=pokemon);

# %%
# 10. No nos interesan las columnas Total, Stage ni Legendary
# Bórralos del DataFrame y vuelve a dibujar el diagrama de caja


pokemon_new = pokemon.drop(["Total", "Stage", "Legendary"], axis=1)
#pokemon_new = pokemon_new.set_index()
plt.figure(figsize=(10,10))
sns.boxplot(data=pokemon_new);

# %%
pokemon
# Out:
#        #        Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur    Grass  Poison    318   45      49       49       65
# 1      2     Ivysaur    Grass  Poison    405   60      62       63       80
# 2      3    Venusaur    Grass  Poison    525   80      82       83      100
# 3      4  Charmander     Fire     NaN    309   39      52       43       60
# 4      5  Charmeleon     Fire     NaN    405   58      64       58       80
# ..   ...         ...      ...     ...    ...  ...     ...      ...      ...
# 146  147     Dratini   Dragon     NaN    300   41      64       45       50
# 147  148   Dragonair   Dragon     NaN    420   61      84       65       70
# 148  149   Dragonite   Dragon  Flying    600   91     134       95      100
# 149  150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 150  151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# 0         65     45      1      False
# 1         80     60      2      False
# 2        100     80      3      False
# 3         50     65      1      False
# 4         65     80      2      False
# ..       ...    ...    ...        ...
# 146       50     50      1      False
# 147       70     70      2      False
# 148      100     80      3      False
# 149       90    130      1       True
# 150      100    100      1      False
#
# [151 rows x 13 columns]

# %%
# 11. Mira cuántos 'Type 1' diferentes hay en el DataFrame
pokemon["Type 1"].value_counts()
# Out:
# Type 1
# Water       28
# Normal      22
# Poison      14
# Fire        12
# Grass       12
# Bug         12
# Electric     9
# Rock         9
# Ground       8
# Psychic      8
# Fighting     7
# Dragon       3
# Ghost        3
# Fairy        2
# Ice          2
# Name: count, dtype: int64

# %%
# 12. Quédate del Dataframe solo con los 'Type 1' iguales a 'Grass', 'Fire' o 'Water'
type_1 = pokemon_new[pokemon_new["Type 1"].isin(["Grass", "Fire", "Water"])]
type_1
# Out:
#            Name Type 1    Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1     Bulbasaur  Grass    Poison   45      49       49       65       65
# 2       Ivysaur  Grass    Poison   60      62       63       80       80
# 3      Venusaur  Grass    Poison   80      82       83      100      100
# 4    Charmander   Fire       NaN   39      52       43       60       50
# 5    Charmeleon   Fire       NaN   58      64       58       80       65
# 6     Charizard   Fire    Flying   78      84       78      109       85
# 7      Squirtle  Water       NaN   44      48       65       50       64
# 8     Wartortle  Water       NaN   59      63       80       65       80
# 9     Blastoise  Water       NaN   79      83      100       85      105
# 37       Vulpix   Fire       NaN   38      41       40       50       65
# 38    Ninetales   Fire       NaN   73      76       75       81      100
# 43       Oddish  Grass    Poison   45      50       55       75       65
# 44        Gloom  Grass    Poison   60      65       70       85       75
# 45    Vileplume  Grass    Poison   75      80       85      110       90
# 54      Psyduck  Water       NaN   50      52       48       65       50
# 55      Golduck  Water       NaN   80      82       78       95       80
# 58    Growlithe   Fire       NaN   55      70       45       70       50
# 59     Arcanine   Fire       NaN   90     110       80      100       80
# 60      Poliwag  Water       NaN   40      50       40       40       40
# 61    Poliwhirl  Water       NaN   65      65       65       50       50
# 62    Poliwrath  Water  Fighting   90      95       95       70       90
# 69   Bellsprout  Grass    Poison   50      75       35       70       30
# 70   Weepinbell  Grass    Poison   65      90       50       85       45
# 71   Victreebel  Grass    Poison   80     105       65      100       70
# 72    Tentacool  Water    Poison   40      40       35       50      100
# 73   Tentacruel  Water    Poison   80      70       65       80      120
# 77       Ponyta   Fire       NaN   50      85       55       65       65
# 78     Rapidash   Fire       NaN   65     100       70       80       80
# 79     Slowpoke  Water   Psychic   90      65       65       40       40
# 80      Slowbro  Water   Psychic   95      75      110      100       80
# 86         Seel  Water       NaN   65      45       55       45       70
# 87      Dewgong  Water       Ice   90      70       80       70       95
# 90     Shellder  Water       NaN   30      65      100       45       25
# 91     Cloyster  Water       Ice   50      95      180       85       45
# 98       Krabby  Water       NaN   30     105       90       25       25
# 99      Kingler  Water       NaN   55     130      115       50       50
# 102   Exeggcute  Grass   Psychic   60      40       80       60       45
# 103   Exeggutor  Grass   Psychic   95      95       85      125       65
# 114     Tangela  Grass       NaN   65      55      115      100       40
# 116      Horsea  Water       NaN   30      40       70       70       25
# 117      Seadra  Water       NaN   55      65       95       95       45
# 118     Goldeen  Water       NaN   45      67       60       35       50
# 119     Seaking  Water       NaN   80      92       65       65       80
# 120      Staryu  Water       NaN   30      45       55       70       55
# 121     Starmie  Water   Psychic   60      75       85      100       85
# 126      Magmar   Fire       NaN   65      95       57      100       85
# 129    Magikarp  Water       NaN   20      10       55       15       20
# 130    Gyarados  Water    Flying   95     125       79       60      100
# 131      Lapras  Water       Ice  130      85       80       85       95
# 134    Vaporeon  Water       NaN  130      65       60      110       95
# 136     Flareon   Fire       NaN   65     130       60       95      110
# 146     Moltres   Fire    Flying   90     100       90      125       85
#
#      Speed
# #
# 1       45
# 2       60
# 3       80
# 4       65
# 5       80
# 6      100
# 7       43
# 8       58
# 9       78
# 37      65
# 38     100
# 43      30
# 44      40
# 45      50
# 54      55
# 55      85
# 58      60
# 59      95
# 60      90
# 61      90
# 62      70
# 69      40
# 70      55
# 71      70
# 72      70
# 73     100
# 77      90
# 78     105
# 79      15
# 80      30
# 86      45
# 87      70
# 90      40
# 91      70
# 98      50
# 99      75
# 102     40
# 103     55
# 114     60
# 116     60
# 117     85
# 118     63
# 119     68
# 120     85
# 121    115
# 126     93
# 129     80
# 130     81
# 131     60
# 134     65
# 136     65
# 146     90

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# 13. Usa un estilo 'whitegrid'
plt.figure(figsize=(15,8))#ajusta el tamaño del gráfico(figsize=(15,8));
sns.set_theme(style= "whitegrid") 
sns.boxplot(data=type_1)
# Out:
# <Axes: >

# %%
type_1["Defense"].max()
# Out:
# np.int64(180)

# %%
type_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52 entries, 0 to 145
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   #          52 non-null     int64
#  1   Name       52 non-null     object
#  2   Type 1     52 non-null     object
#  3   Type 2     23 non-null     object
#  4   Total      52 non-null     int64
#  5   HP         52 non-null     int64
#  6   Attack     52 non-null     int64
#  7   Defense    52 non-null     int64
#  8   Sp. Atk    52 non-null     int64
#  9   Sp. Def    52 non-null     int64
#  10  Speed      52 non-null     int64
#  11  Stage      52 non-null     int64
#  12  Legendary  52 non-null     bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 5.3+ KB

# %%
print(type_1["Defense"].describe())
# Out:
# count     52.000000
# mean      72.230769
# std       24.964772
# min       35.000000
# 25%       55.000000
# 50%       67.500000
# 75%       83.500000
# max      180.000000
# Name: Defense, dtype: float64

# %%
print(type_1.head())
# Out:
#          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# #
# 1   Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 2     Ivysaur  Grass  Poison  60      62       63       80       80     60
# 3    Venusaur  Grass  Poison  80      82       83      100      100     80
# 4  Charmander   Fire     NaN  39      52       43       60       50     65
# 5  Charmeleon   Fire     NaN  58      64       58       80       65     80

# %%
# 14. Pinta diagramas de violín con el DataFrame filtrado por los 3 tipos

sns.set_theme(style= "whitegrid")

sns.violinplot(x= "Type 1", y="Attack", data= type_1, palette= "pastel")



# Rotar las etiquetas del eje X para evitar que se sobrepongan
# Out:
# C:\Users\nagor\AppData\Local\Temp\ipykernel_13596\2299570563.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x= "Type 1", y="Attack", data= type_1, palette= "pastel")
# <Axes: xlabel='Type 1', ylabel='Attack'>

# %%
# 15. Escribe una lista de colores con valores '#78C850', '#F08030',  '#6890F0'
colores = ['#78C850', '#F08030',  '#6890F0']

# %%
# 16. Pinta de nuevo los diagramas de violín añadiendo esos colores en la paleta (palette)
sns.set_theme(style= "whitegrid")

violin_diag =sns.violinplot(x= "Type 1", y="Attack", data= type_1, palette= colores)
# Out:
# C:\Users\nagor\AppData\Local\Temp\ipykernel_13596\2902421900.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   violin_diag =sns.violinplot(x= "Type 1", y="Attack", data= type_1, palette= colores)

# %%
# 17. Con el diagrama de violín vemos la forma de la distribución, pero no sabemos si Grass tiene muchos puntos y Fire tiene muy pocos.
# Para ver esto, usamos el swarmplot.
# Pinta el último diagrama de violines pero con un swarmplot en lugar de un violin

sns.set_theme(style= "whitegrid")

sns.swarmplot(x= "Type 1", y="Attack", data= type_1, palette= colores)
#sns.swarmplot(x= "Type 1", y="Attack", data=type_1)
# Out:
# C:\Users\nagor\AppData\Local\Temp\ipykernel_13596\1332110631.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x= "Type 1", y="Attack", data= type_1, palette= colores)
# <Axes: xlabel='Type 1', ylabel='Attack'>

# %%
# 18. Queremos ver los violines a la vez que los swarm, los podemos pintar juntos. 
# Elimina los diagramas de caja dentro de los violines con el parámetro inner = None y pon una transparencia de 0.9 en el swarmplot
# Pon un título con pyplot (como siempre)
sns.set_theme(style= "whitegrid")

sns.violinplot(x= "Type 1", y="Attack", data= type_1, palette= colores)
sns.swarmplot(x= "Type 1", y="Attack", data=type_1, color= "k")
# Out:
# C:\Users\nagor\AppData\Local\Temp\ipykernel_13596\151305580.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x= "Type 1", y="Attack", data= type_1, palette= colores)
# <Axes: xlabel='Type 1', ylabel='Attack'>

# %%
# 19. Veamos la función melt() de pandas. Melt toma los valores de varias columnas y los junta todos en una misma columna nueva.
# Dado un DataFrame, melt recibe varios parámetros:
# * qué columnas del DataFrame se quedan igual
# * qué nombres de columnas del dataframe pasan a ser una columna nueva
# * cómo queremos llamar esas nuevas columnas

# Primero recuerda el Dataframe df_grass_fire_water con las primeras 5 filas

type_1
# Out:
#            Name Type 1    Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1     Bulbasaur  Grass    Poison   45      49       49       65       65
# 2       Ivysaur  Grass    Poison   60      62       63       80       80
# 3      Venusaur  Grass    Poison   80      82       83      100      100
# 4    Charmander   Fire       NaN   39      52       43       60       50
# 5    Charmeleon   Fire       NaN   58      64       58       80       65
# 6     Charizard   Fire    Flying   78      84       78      109       85
# 7      Squirtle  Water       NaN   44      48       65       50       64
# 8     Wartortle  Water       NaN   59      63       80       65       80
# 9     Blastoise  Water       NaN   79      83      100       85      105
# 37       Vulpix   Fire       NaN   38      41       40       50       65
# 38    Ninetales   Fire       NaN   73      76       75       81      100
# 43       Oddish  Grass    Poison   45      50       55       75       65
# 44        Gloom  Grass    Poison   60      65       70       85       75
# 45    Vileplume  Grass    Poison   75      80       85      110       90
# 54      Psyduck  Water       NaN   50      52       48       65       50
# 55      Golduck  Water       NaN   80      82       78       95       80
# 58    Growlithe   Fire       NaN   55      70       45       70       50
# 59     Arcanine   Fire       NaN   90     110       80      100       80
# 60      Poliwag  Water       NaN   40      50       40       40       40
# 61    Poliwhirl  Water       NaN   65      65       65       50       50
# 62    Poliwrath  Water  Fighting   90      95       95       70       90
# 69   Bellsprout  Grass    Poison   50      75       35       70       30
# 70   Weepinbell  Grass    Poison   65      90       50       85       45
# 71   Victreebel  Grass    Poison   80     105       65      100       70
# 72    Tentacool  Water    Poison   40      40       35       50      100
# 73   Tentacruel  Water    Poison   80      70       65       80      120
# 77       Ponyta   Fire       NaN   50      85       55       65       65
# 78     Rapidash   Fire       NaN   65     100       70       80       80
# 79     Slowpoke  Water   Psychic   90      65       65       40       40
# 80      Slowbro  Water   Psychic   95      75      110      100       80
# 86         Seel  Water       NaN   65      45       55       45       70
# 87      Dewgong  Water       Ice   90      70       80       70       95
# 90     Shellder  Water       NaN   30      65      100       45       25
# 91     Cloyster  Water       Ice   50      95      180       85       45
# 98       Krabby  Water       NaN   30     105       90       25       25
# 99      Kingler  Water       NaN   55     130      115       50       50
# 102   Exeggcute  Grass   Psychic   60      40       80       60       45
# 103   Exeggutor  Grass   Psychic   95      95       85      125       65
# 114     Tangela  Grass       NaN   65      55      115      100       40
# 116      Horsea  Water       NaN   30      40       70       70       25
# 117      Seadra  Water       NaN   55      65       95       95       45
# 118     Goldeen  Water       NaN   45      67       60       35       50
# 119     Seaking  Water       NaN   80      92       65       65       80
# 120      Staryu  Water       NaN   30      45       55       70       55
# 121     Starmie  Water   Psychic   60      75       85      100       85
# 126      Magmar   Fire       NaN   65      95       57      100       85
# 129    Magikarp  Water       NaN   20      10       55       15       20
# 130    Gyarados  Water    Flying   95     125       79       60      100
# 131      Lapras  Water       Ice  130      85       80       85       95
# 134    Vaporeon  Water       NaN  130      65       60      110       95
# 136     Flareon   Fire       NaN   65     130       60       95      110
# 146     Moltres   Fire    Flying   90     100       90      125       85
#
#      Speed
# #
# 1       45
# 2       60
# 3       80
# 4       65
# 5       80
# 6      100
# 7       43
# 8       58
# 9       78
# 37      65
# 38     100
# 43      30
# 44      40
# 45      50
# 54      55
# 55      85
# 58      60
# 59      95
# 60      90
# 61      90
# 62      70
# 69      40
# 70      55
# 71      70
# 72      70
# 73     100
# 77      90
# 78     105
# 79      15
# 80      30
# 86      45
# 87      70
# 90      40
# 91      70
# 98      50
# 99      75
# 102     40
# 103     55
# 114     60
# 116     60
# 117     85
# 118     63
# 119     68
# 120     85
# 121    115
# 126     93
# 129     80
# 130     81
# 131     60
# 134     65
# 136     65
# 146     90

# %%
# 20. Queremos dejar igual las variables 'Name' y 'Type 1'
# Queremos añadir una columa nueva cuyos valores sean las columnas que queremos apilar y que se llame 'New Column'
# Escribimos df_gfw.melt(id_vars=['Name', 'Type 1'], value_vars=[...], var_name='New Column')

type_1_melted = type_1.melt(id_vars=['Name', 'Type 1'], value_vars=['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed'], var_name='New Column')

type_1_melted
# Out:
#            Name Type 1 New Column  value
# 0     Bulbasaur  Grass         HP     45
# 1       Ivysaur  Grass         HP     60
# 2      Venusaur  Grass         HP     80
# 3    Charmander   Fire         HP     39
# 4    Charmeleon   Fire         HP     58
# ..          ...    ...        ...    ...
# 307    Gyarados  Water      Speed     81
# 308      Lapras  Water      Speed     60
# 309    Vaporeon  Water      Speed     65
# 310     Flareon   Fire      Speed     65
# 311     Moltres   Fire      Speed     90
#
# [312 rows x 4 columns]

# %%
# 21. Pintamos el swarmplot con el melted y entendemos la información
sns.swarmplot(data=type_1_melted, x="New Column", y= "value", hue= "Type 1", legend=True)
# Out:
# <Axes: xlabel='New Column', ylabel='value'>

# %%
# 22. Basándote en el gráfico anterior, define el tamaño de la figura en (10,6) (usa plt)
# En el swarmplot añade el argumento dodge a True y usa la anterior paleta de colores Pokemon

# Dodge en inglés es "esquivar", ¿qué diferencia ves?

# Usando plt 
# fija el límite del eje Y entre 0 y 200
# fija la leyenda con bbox_to_anchor en upper left. Pista: upper left es el código 2 y se usa el parámetro loc.



nuevo = plt.figure(figsize=(10,6))
sns.swarmplot(data=type_1_melted, x="New Column", y= "value", hue= "Type 1", legend=True, dodge=True)
plt.ylim(0,200)
;
# Out:
# ''

# %%
# Observa que incluso usando Seaborn, usamos Pyplot para trabajar con los ejes, la leyenda y el tamaño
# Lo importante es que Seaborn y Pyplot conviven bien juntos

# %%
# 23. Mapas de calor
# Calcula las correlaciones del primer DataFrame original df
# Pista: las correlaciones se calculan con el método corr()
# Recuerda: las correlaciones miden entre dos variables, si varío una, cuánto me varía la otra (cómo están de relacionadas)

pokemon.head()
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 4  Charmander   Fire     NaN    309  39      52       43       60       50
# 5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# #
# 1     45      1      False
# 2     60      2      False
# 3     80      3      False
# 4     65      1      False
# 5     80      2      False

# %%
numeric_pok = pokemon.select_dtypes(include=["float64", "int64"])
pok_corr = numeric_pok.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(pok_corr, annot=True, cmap="coolwarm", vmin=-1, vmax=1, linewidths=0.5)
# Out:
# <Axes: >

# %%
pokemon.corr(numeric_only=True)
# Out:
#               Total        HP    Attack   Defense   Sp. Atk   Sp. Def  \
# Total      1.000000  0.576591  0.670939  0.508694  0.680745  0.774383
# HP         0.576591  1.000000  0.306768  0.119782  0.236649  0.490978
# Attack     0.670939  0.306768  1.000000  0.491965  0.146312  0.369069
# Defense    0.508694  0.119782  0.491965  1.000000  0.187569  0.139912
# Sp. Atk    0.680745  0.236649  0.146312  0.187569  1.000000  0.522907
# Sp. Def    0.774383  0.490978  0.369069  0.139912  0.522907  1.000000
# Speed      0.506950 -0.040939  0.194701 -0.053252  0.411516  0.392656
# Stage      0.504224  0.249207  0.361321  0.270861  0.391712  0.358308
# Legendary  0.328412  0.172441  0.147486  0.141576  0.334159  0.215314
#
#               Speed     Stage  Legendary
# Total      0.506950  0.504224   0.328412
# HP        -0.040939  0.249207   0.172441
# Attack     0.194701  0.361321   0.147486
# Defense   -0.053252  0.270861   0.141576
# Sp. Atk    0.411516  0.391712   0.334159
# Sp. Def    0.392656  0.358308   0.215314
# Speed      1.000000  0.240042   0.199969
# Stage      0.240042  1.000000  -0.142508
# Legendary  0.199969 -0.142508   1.000000

# %% [markdown]
# ### ¿la correlación entre qué valores se encuentra?
# Tenemos una correlación negativa significante entre nivel de defensa y velocidad, a más defensa, menos velocidad. Parece que también existe una correlación negativa entre velocidad y salud. A más velocidad, menos salud.
# Para la correlación positiva, hay una relacion significativa entre SP. Attack (ataque especial) y S.P.Defense (Defensa especial). Cuando más uno, más el otro.
# El segundo es a cuanto más SP Defense, más HP(Salud) y es exactamente el mismo nivel de correlación que a cuanto más ataque, má defensa

# %% [markdown]
# ### la autocorrelación es la correlación de una variable consigo misma, ¿qué aprecias?
# Lo que aprecio es que la velocidad es un parámero importante para determinar el nivel de HP y defensa que tiene un pokemon, ya que a más velocidad, menos valor de HP y/o Defensa
#  Por otro lado, me indica que tener un S.P A ttack alto, ayuda y puede determinar un S.P. Defense tamnbién alt

# %% [markdown]
# ### Encuentra dos variables que veas que están fuertemente relacionadas según la correlación
#
# Pues S.P. Attack alto está relacionado con un S.P. Defense alto, por ejemplo

# %% [markdown]
# ### Si tuvieras una matriz de correlación muy grande y te cobrasen por cada dato que lees, ¿qué harías? (ML)
#
# Lo ideal sería hacer una buena limpieza y filtrado de los datos antes de empezar a analizarlos. Se pdrían usar estructuras de datos más eficientes por ejemplo

# %%
pokemon
# Out:
#            Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# #
# 1     Bulbasaur    Grass  Poison    318   45      49       49       65
# 2       Ivysaur    Grass  Poison    405   60      62       63       80
# 3      Venusaur    Grass  Poison    525   80      82       83      100
# 4    Charmander     Fire     NaN    309   39      52       43       60
# 5    Charmeleon     Fire     NaN    405   58      64       58       80
# ..          ...      ...     ...    ...  ...     ...      ...      ...
# 147     Dratini   Dragon     NaN    300   41      64       45       50
# 148   Dragonair   Dragon     NaN    420   61      84       65       70
# 149   Dragonite   Dragon  Flying    600   91     134       95      100
# 150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# #
# 1         65     45      1      False
# 2         80     60      2      False
# 3        100     80      3      False
# 4         50     65      1      False
# 5         65     80      2      False
# ..       ...    ...    ...        ...
# 147       50     50      1      False
# 148       70     70      2      False
# 149      100     80      3      False
# 150       90    130      1       True
# 151      100    100      1      False
#
# [151 rows x 12 columns]

# %%
# 24. Pinta el histograma y la densidad de probabilidad del nivel de defensa usando el DataFrame original

#kdl
defensa = pokemon[["Name", "Defense"]]
defensa
# Out:
#            Name  Defense
# #
# 1     Bulbasaur       49
# 2       Ivysaur       63
# 3      Venusaur       83
# 4    Charmander       43
# 5    Charmeleon       58
# ..          ...      ...
# 147     Dratini       45
# 148   Dragonair       65
# 149   Dragonite       95
# 150      Mewtwo       90
# 151         Mew      100
#
# [151 rows x 2 columns]

# %%
sns.histplot(data=pokemon, x= "Defense", kde=True, bins=20)
# Out:
# <Axes: xlabel='Defense', ylabel='Count'>

# %%
# 25. Pinta un diagrama de barras de la columna 'Type 1' usando el DataFrame original
# Usa un sns.countplot
# Usa plt.xticks y gira las etiquetas
plt.figure(figsize=(12,7))
sns.countplot(x= "Type 1", data=pokemon, palette="pastel", legend=False)
plt.xticks(rotation= 45)

plt.show()
# Out:
# C:\Users\nagor\AppData\Local\Temp\ipykernel_13596\643273610.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x= "Type 1", data=pokemon, palette="pastel", legend=False)

# %%
# 26. Usa catplot con el DataFrame original. Muestra el valor de Defense según el 'Type 1', muestra un subplot para legendarios y otro para no legendarios
# y divide los colores según el Type 2

# Pinta un catplot para 'Defense' según 'Type 1', y divide por 'Legendary' (legendario vs no legendario)

g= sns.catplot( data= pokemon,
            x= "Type 1", y = "Defense", hue ="Type 2",
              col="Legendary")# Divide en subgráficos para los legendarios y no legendarios
for ax in g.axes.flat:
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45)   #est lo he copiado de CHATGPT para que me giren los nombres
    
plt.subplots_adjust(top=0.85)  # Espacio para el título
# Out:
# C:\Users\nagor\AppData\Local\Temp\ipykernel_13596\526018111.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# C:\Users\nagor\AppData\Local\Temp\ipykernel_13596\526018111.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# %%
# 27. Muestra una función distribución de probabilidad con kdeplot (curvas de nivel) de la defensa respecto al ataque.
# Di un bin 2D donde caigan muchos puntos (ataque, defensa).
sns.kdeplot(x= "Defense", y= "Attack", data=pokemon, cmap="Blues", fill=True, 
            levels=10, gridsize=100)  # Ajustamos el 'gridsize' para más detalle


plt.title("Distribución de Defensa vs Ataque", fontsize=16)
# Out:
# Text(0.5, 1.0, 'Distribución de Defensa vs Ataque')

# %%
# 28. Pinta una distribución de probabilidad conjunta con jointplot, pintando la defensa respecto al ataque del DataFrame original

# Sirve para mostrar la relación entre dos variables, junto con sus distribuciones marginales
sns.jointplot(x=pokemon['Defense'],
              y=pokemon['Attack'],
              color="#4CB391",
             height = 8);
